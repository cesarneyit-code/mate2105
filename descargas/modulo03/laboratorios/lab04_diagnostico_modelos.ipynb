# %% [markdown]
# # Lab 4 - Diagnóstico de modelos

# %% [markdown]
# ## Instrucciones
# Complete las funciones indicadas. No cambie nombres ni firmas: el autograder las busca por nombre.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score, learning_curve
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Funciones a implementar

# %%
def make_splits(X, y, test_size=0.2, dev_size=0.25, random_state=42):
    # TODO: devolver X_train, X_dev, X_test, y_train, y_dev, y_test con estratificación
    raise NotImplementedError


def metric_report(y_true, y_pred):
    # TODO: devolver accuracy, precision, recall, f1 y confusion_matrix
    raise NotImplementedError


def build_baseline(strategy="most_frequent"):
    # TODO: devolver DummyClassifier
    raise NotImplementedError


def build_pipeline(C=1.0, random_state=42):
    # TODO: devolver Pipeline con StandardScaler y LogisticRegression
    raise NotImplementedError


def cross_validate_model(model, X, y, cv=5, scoring="f1"):
    # TODO: devolver dict con mean, std, scores
    raise NotImplementedError


def learning_curve_summary(model, X, y, train_sizes=None, cv=5, scoring="f1"):
    # TODO: devolver train_sizes, train_scores_mean, validation_scores_mean
    raise NotImplementedError


def slice_error_report(X, y_true, y_pred, feature, threshold):
    # TODO: devolver DataFrame con columnas slice, n, f1, errors
    raise NotImplementedError


def choose_best_model(results, metric="f1"):
    """Elige por mayor mean - std y devuelve (nombre, puntaje).

    El puntaje es una regla heurística de selección, no un intervalo de confianza.
    """
    # TODO: comparar todos los candidatos con la regla indicada
    raise NotImplementedError

# %% [markdown]
# ## Prueba local sugerida

# %%
data = load_breast_cancer(as_frame=True)
X = data.data
y = data.target
# Cuando complete las funciones:
# splits = make_splits(X, y, random_state=42)
# X_train, X_dev, X_test, y_train, y_dev, y_test = splits
# pipe = build_pipeline(C=1.0)
# print(cross_validate_model(pipe, X_train, y_train, cv=3))

# %% [markdown]
# ## Contrato probabilístico
#
# Completa las respuestas estructuradas para identificar el objeto poblacional, la aproximación muestral y la fuente de incertidumbre de esta evaluación.

# %%
probability_answers = {
    'test_metric': '',
    'cv_folds': '',
    'bootstrap_unit': '',
    'slice_metric': '',
}

# %% [markdown]
# ## Interpretación manual
# Responda: con la evidencia del notebook, ¿qué modelo elegiría, cuál es el diagnóstico principal y cuál sería el siguiente experimento?
