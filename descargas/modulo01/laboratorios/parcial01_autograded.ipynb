# %% [markdown]
# # Parcial 1 autograded: probabilidad aplicada y algoritmos
#
# Completa funciones y respuestas estructuradas. No cambies firmas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes, load_breast_cancer, make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %%
def predict_linear(X, theta):
    raise NotImplementedError


def mse_gradient(X, y, theta):
    raise NotImplementedError


def ridge_closed_form(X, y, alpha):
    raise NotImplementedError


def sigmoid(z):
    raise NotImplementedError


def log_loss_binary(y_true, proba, eps=1e-15):
    raise NotImplementedError


def classification_metrics(y_true, proba, threshold=0.5):
    raise NotImplementedError


def bernoulli_standard_error(indicators):
    # Error estándar plug-in de la media de indicadores 0/1.
    raise NotImplementedError


structured_answers = {
    'normal_equation': '',
    'ridge_effect': '',
    'test_set_role': '',
    'metric_status': '',
    'log_loss_target': '',
    'conditional_squared_target': '',
}

probability_answers = structured_answers

# %% [markdown]
# ## Explicación manual
#
# Si un modelo mejora el baseline por poco, identifica la cantidad poblacional que intenta estimar la mejora, su incertidumbre y la evidencia adicional necesaria antes de recomendarlo.
