# %% [markdown]
# # Parcial 2 autograded
#
# Implementa las funciones solicitadas. No cambies nombres ni argumentos.

# %%
import hashlib
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import load_breast_cancer, make_blobs
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Softmax y cross-entropy

# %%
def stable_softmax(logits):
    """Devuelve softmax fila a fila con estabilidad numérica."""
    # TODO
    raise NotImplementedError


def cross_entropy_from_probabilities(proba, y):
    """Devuelve entropía cruzada promedio para etiquetas enteras."""
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 2. Particiones y validación

# %%
def make_stratified_splits(X, y, test_size=0.2, dev_size=0.25, random_state=42):
    """Devuelve X_train, X_dev, X_test, y_train, y_dev, y_test."""
    # TODO
    raise NotImplementedError


def cv_summary(scores):
    """Devuelve mean, std y lower_bound=mean-std."""
    # TODO
    raise NotImplementedError


def select_model_by_cv(results):
    """Elige el modelo con mayor mean-std. Devuelve nombre y lower_bound."""
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 3. PCA y K-Means

# %%
def pca_svd_summary(X, n_components):
    """Devuelve components, scores, explained_variance_ratio, cumulative_variance y reconstruction_error."""
    # TODO
    raise NotImplementedError


def choose_k_by_silhouette(X, k_values, random_state=42):
    """Devuelve best_k y scores={k: silhouette}."""
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## 4. Manifest reproducible

# %%
def file_sha256(path):
    """Devuelve hash SHA-256 hexadecimal de un archivo."""
    # TODO
    raise NotImplementedError


def build_reproducibility_manifest(params, metrics, artifact_paths):
    """Devuelve manifest con params, metrics y hashes de artefactos."""
    # TODO
    raise NotImplementedError

# %% [markdown]
# ## Parte manual
#
# Responde en 120 a 180 palabras:
#
# Tu modelo final mejora el baseline, pero tiene un slice con desempeño bajo. ¿Qué evidencia adicional pedirías antes de recomendar una decisión real y cómo lo documentarías de forma reproducible?
